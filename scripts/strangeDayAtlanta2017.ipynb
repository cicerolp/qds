# %%
import requests
import ast
import json
import math
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datasetName      = "on_time_performance"
payloadDimension = "dep_delay"
initialTime      = 0
finalTime        = 0
stepSize         = 24*3600
threshold        = 0

# %%
#get parameters
r=requests.get("http://localhost:7000/api/schema/dataset=" + datasetName )
schema = json.loads(r.text)
numIndexDimensions = len(schema['index_dimensions'])
for i in xrange(numIndexDimensions):
    dimension = schema['index_dimensions'][i]
    if(dimension["type"] == "temporal"):
        #print i,dimension["hint"]
        tokens      = dimension["hint"].split("|")
        initialTime = int(tokens[0].strip())
        finalTime   = int(tokens[1].strip())+stepSize
        
finalTime = 1514764800

# %%
queryPrefix = "http://localhost:7000/api/"
pipelinePrefix = "pipeline/"
joinString  = "join=" + "right_join" + "/"
thresholdString = "threshold=" + str(threshold) + "/"
sourceString = "source/aggr=average."+ payloadDimension + "_g/dataset=" + datasetName + "/" + \
                "const=origin_airport.tile.(%d:%d:%d:%d)/group=origin_airport/" + \
    "const=unique_carrier.values.(1529)/"
destinationString = "destination/aggr=inverse." + payloadDimension + "_t.($)/dataset=on_time_performance/" + \
                     "const=origin_airport.tile.(%d:%d:%d:%d)/group=origin_airport/"+ \
    "const=unique_carrier.values.(1529)/"

# %%
auxArray = []
def getQueryString(x,y,z,r,timeString):
    return queryPrefix + pipelinePrefix + joinString + thresholdString + \
            sourceString%(x,y,z,r) + "/" + timeString + "/" + destinationString%(x,y,z,r) 

def findStrangenessCoef(start,end):
    timeConstraint = "const=crs_dep_time.interval.(" + str(start) + ":" + str(end) + ")"
    xMin = 3
    xMax = 10
    yMin = 10
    yMax = 15
    z = 11
    r = 5
            
    #
    queryString = getQueryString(0,0,0,15,timeConstraint)   
    response = requests.get(queryString) 
    entries  = json.loads(response.text)           
    numEntries = len(entries[0])
    #
    result = {"numNegativeEntries":0,"negativeEntries":0,"depthEntries":0, "numEntries":0,"nonNegativeEntries":[], "totalEntries":0}

    
    for i in xrange(numEntries):
        entry = entries[0][i]
        auxArray.append(entry)
        result["totalEntries"] += 1

        if entry[4] < 0:
            result["numNegativeEntries"] += 1
            result["negativeEntries"] += entry[4]
        else:
            result["numEntries"] += 1
            depthValue = math.fabs(entry[4]-0.5)
            result["nonNegativeEntries"].append(depthValue)
            result["depthEntries"] += depthValue
    return result

# %%
numTimeSteps = (finalTime - initialTime)/stepSize
results = []

for i in xrange(numTimeSteps):
    start = initialTime + i * stepSize
    end   = start + stepSize
    value = findStrangenessCoef(start,end)
    value["index"] = i
    value["time"] = start
    results.append(value)

# %%
print "************** Max Depth" 
sortedResult = sorted(results, key=lambda k: np.mean(k['depthEntries']))

numCompanies = max([t["totalEntries"] for t in results])

for i in xrange(10):    
    entry = sortedResult[364-i]
    print datetime.datetime.utcfromtimestamp(entry["time"]), 2*entry["depthEntries"]/numCompanies


print numCompanies
# Out:
# ************** Max Depth
# 2017-08-03 00:00:00 0.777438854629
# 2017-08-04 00:00:00 0.719100931829
# 2017-08-02 00:00:00 0.701410804283
# 2017-01-02 00:00:00 0.68818112666
# 2017-04-05 00:00:00 0.663831126961
# 2017-06-19 00:00:00 0.662560642443
# 2017-07-20 00:00:00 0.657865387472
# 2017-06-14 00:00:00 0.657768939029
# 2017-06-15 00:00:00 0.649950845675
# 2017-12-26 00:00:00 0.648734373125
# 88

# %%
sorted([t["depthEntries"] for t in results])
# Out:
# [61.51728879660368,
#  69.17890357784927,
#  70.13433393836021,
#  71.78126594051719,
#  72.50715061277151,
#  72.7508192062378,
#  73.15969284716994,
#  73.28720824420452,
#  73.40956031158566,
#  73.57335729338229,
#  73.77780430391431,
#  74.56129698455334,
#  74.59994193539023,
#  74.65237382752821,
#  74.86028080433607,
#  75.98313614353538,
#  76.91361812874675,
#  77.05590542778373,
#  77.4253342449665,
#  77.73648973042145,
#  77.9619670221582,
#  78.11452844366431,
#  78.46352623030543,
#  78.4835185483098,
#  78.53305719047785,
#  78.57402002159506,
#  78.65684609115124,
#  78.942766754888,
#  79.40288758836687,
#  79.59015302546322,
#  79.64481992833316,
#  79.72693376615644,
#  79.84596215188503,
#  79.87753077223897,
#  79.94584634900093,
#  80.04962082579732,
#  80.21244027838111,
#  80.26424244046211,
#  80.2905996516347,
#  80.3061768040061,
#  80.41155532747507,
#  80.53719183057547,
#  80.63518654555082,
#  80.67379186674953,
#  81.32772456482053,
#  81.54763879068196,
#  81.56287198513746,
#  81.6014285814017,
#  81.86111398041248,
#  81.89905958808959,
#  81.90750314574689,
#  82.09387842565775,
#  82.63958317041397,
#  82.74091017991304,
#  82.77347423508763,
#  82.86306368932128,
#  82.95111876167357,
#  83.09461437165737,
#  83.30246302857995,
#  83.32532105781138,
#  83.36836499348283,
#  83.37613199278712,
#  83.42318123206496,
#  83.7173358425498,
#  83.78729920089245,
#  83.79445803165436,
#  83.8092137798667,
#  83.95697010308504,
#  84.33706944063306,
#  84.35650615394115,
#  84.36141912639141,
#  84.6621807962656,
#  84.67752874083817,
#  84.99698368832469,
#  85.07343973964453,
#  85.0915786549449,
#  85.10696282424033,
#  85.14793660491705,
#  85.1577355414629,
#  85.23979674093425,
#  85.46482453122735,
#  85.46884050965309,
#  85.47476121783257,
#  85.58140466362238,
#  85.69881958514452,
#  85.88881342485547,
#  86.0722571387887,
#  86.11767376959324,
#  86.26753258705139,
#  86.33461473882198,
#  86.42642194777727,
#  86.47593159601092,
#  86.4816738832742,
#  86.6412102766335,
#  86.73554158955812,
#  86.75642627105117,
#  86.78254901990294,
#  86.86360106244683,
#  86.9144479483366,
#  86.94847366772592,
#  87.05451495572925,
#  87.16374814510345,
#  87.17359952256083,
#  87.25721769407392,
#  87.3185604326427,
#  87.32898749411106,
#  87.35060824453831,
#  87.39354391396046,
#  87.40295875072479,
#  87.5903400927782,
#  87.60820226371288,
#  87.65731267817318,
#  87.66769149526954,
#  87.73629217594862,
#  87.78790351375937,
#  87.88387320935726,
#  87.89532266743481,
#  87.97016165405512,
#  87.98293640464544,
#  88.01805081218481,
#  88.04909965768456,
#  88.06897581368685,
#  88.07516547665,
#  88.11816737055779,
#  88.17228781990707,
#  88.41299247182906,
#  88.46813049912453,
#  88.53332496481016,
#  88.58865436166525,
#  88.65885219350457,
#  88.66439715214074,
#  88.68566811829805,
#  88.7119488120079,
#  89.13335464894772,
#  89.18666416406631,
#  89.21698276884854,
#  89.27558950893581,
#  89.27718056552112,
#  89.34582290425897,
#  89.42716876417398,
#  89.46109566837549,
#  89.8539246097207,
#  89.87703926861286,
#  89.9262459948659,
#  89.95832774788141,
#  90.04370138794184,
#  90.12848069705069,
#  90.15212622657418,
#  90.25492062419653,
#  90.30944430083036,
#  90.33785624057055,
#  90.56086507439613,
#  90.57714369753376,
#  90.58250387571752,
#  90.67128063738346,
#  90.81944173574448,
#  90.83805083855987,
#  90.88244300335646,
#  90.89781459793448,
#  91.0362035036087,
#  91.1139543056488,
#  91.11585986986756,
#  91.17369090765715,
#  91.3136840313673,
#  91.32700638100505,
#  91.41282705962658,
#  91.46524503827095,
#  91.51228392124176,
#  91.59939356148243,
#  91.73456375300884,
#  91.76245500892401,
#  92.04513561353087,
#  92.08424034900963,
#  92.17998073622584,
#  92.26181312650442,
#  92.4314153790474,
#  92.48835651576519,
#  92.62099151313305,
#  92.91891509667039,
#  92.97527238540351,
#  93.0537966415286,
#  93.05678504705429,
#  93.14599475264549,
#  93.14987013861537,
#  93.18641980737448,
#  93.45955036766827,
#  93.54382222890854,
#  93.58478920906782,
#  93.60429004579782,
#  93.62735418230295,
#  93.62862277962267,
#  93.85576845519245,
#  93.92907155305147,
#  94.03901669383049,
#  94.26724675111473,
#  94.27260676398873,
#  94.28340546786785,
#  94.3014495074749,
#  94.34914711862803,
#  94.46072347089648,
#  94.47618542425334,
#  94.63899944722652,
#  94.84721338748932,
#  95.00773408263922,
#  95.02386971563101,
#  95.03447260707617,
#  95.13062177598476,
#  95.22282046824694,
#  95.41200783476233,
#  95.51789749599993,
#  95.5651716478169,
#  95.60912409424782,
#  95.68796294555068,
#  95.748739361763,
#  95.87279342859983,
#  96.0847190618515,
#  96.09910277370363,
#  96.10344029963017,
#  96.23075825348496,
#  96.25075760483742,
#  96.49061764031649,
#  96.54554758965969,
#  96.54851737618446,
#  96.5553040355444,
#  96.56982957944274,
#  96.61960946023464,
#  96.62297362089157,
#  96.76385293994099,
#  96.81685550510883,
#  96.94127973914146,
#  96.94638770492747,
#  96.94874987006187,
#  97.09338875301182,
#  97.23210317641497,
#  97.58911890536547,
#  97.6107044480741,
#  97.61433809623122,
#  97.68414817750454,
#  97.75993568077683,
#  98.0331160351634,
#  98.0594013556838,
#  98.17986633256078,
#  98.19451865553856,
#  98.2097237445414,
#  98.35263483412564,
#  98.47131120413542,
#  98.49622018635273,
#  98.50075226277113,
#  98.62820778414607,
#  98.69857063144445,
#  98.75731607526541,
#  98.82446430623531,
#  98.93965192139149,
#  98.96386890858412,
#  99.05505662411451,
#  99.22573088109493,
#  99.2398212775588,
#  99.2665858566761,
#  99.28882210701704,
#  99.30419737100601,
#  99.38515392877162,
#  99.88898932933807,
#  100.06444108486176,
#  100.31745439767838,
#  100.33396200463176,
#  100.47913288325071,
#  100.58019714802504,
#  100.58961822092533,
#  100.63484200835228,
#  100.70668160915375,
#  100.89767193235457,
#  101.11208879202604,
#  101.18222094327211,
#  101.21477292105556,
#  101.36242481693625,
#  101.37655470147729,
#  101.47000187309459,
#  101.75092463195324,
#  101.81369899399579,
#  101.84932088851929,
#  102.17461024224758,
#  102.18393540382385,
#  102.2014072611928,
#  102.22643759846687,
#  102.37538885325193,
#  102.86290588974953,
#  103.08496073633432,
#  103.36987295001745,
#  103.39229340106249,
#  103.40075615048409,
#  103.44845050573349,
#  103.4657862894237,
#  103.70567987859249,
#  103.8908156901598,
#  104.01332497596741,
#  104.26697550714016,
#  104.43354611098766,
#  104.55764526128769,
#  104.76187494210899,
#  104.77797939628363,
#  104.78450351953506,
#  104.84906318038702,
#  104.87705574557185,
#  104.93286949023604,
#  105.26087509095669,
#  105.3129422813654,
#  105.54217398166656,
#  105.6547115072608,
#  105.68470059335232,
#  105.81086528301239,
#  105.83438888937235,
#  105.90710740536451,
#  106.22303142398596,
#  106.27418541163206,
#  106.52301662415266,
#  106.63105754554272,
#  106.66197653114796,
#  107.06425737403333,
#  107.39650946110487,
#  107.45360364206135,
#  107.49458959326148,
#  107.54169295169413,
#  107.80540978908539,
#  107.8795877546072,
#  108.39218385517597,
#  108.81829137727618,
#  108.86286973953247,
#  109.23579901643097,
#  109.46818614006042,
#  109.46922654099762,
#  109.61634251475334,
#  109.96926268935204,
#  109.98333002626896,
#  110.1520878970623,
#  110.20118320733309,
#  110.54233557730913,
#  110.5541570931673,
#  110.93879640474916,
#  111.0387089625001,
#  111.32754231989384,
#  111.4105767160654,
#  111.54038148932159,
#  111.55342275649309,
#  111.64021199941635,
#  111.80579400062561,
#  112.4326740205288,
#  112.4778556637466,
#  112.58313515782356,
#  113.16941002570093,
#  113.22591992467642,
#  114.35891213081777,
#  114.52867756783962,
#  114.78922963142395,
#  114.84513298794627,
#  115.63433004822582,
#  121.92333662509918,
#  122.78905307501554,
#  125.04239356517792,
#  125.33934558928013,
#  125.37938012182713,
#  126.17560925148427,
#  130.84359151124954,
#  131.88395902514458,
#  133.86590212583542,
#  134.11779296398163]

# %%
plt.hist([t["depthEntries"] for t in results])
#plt.hist([t["numNegativeEntries"] for t in results])
# Out:
# (array([  4.,   9.,  20.,  25.,  46.,  77.,  83.,  65.,  21.,  15.]),
#  array([ 38.00835597,  41.84868191,  45.68900785,  49.5293338 ,
#          53.36965974,  57.20998568,  61.05031162,  64.89063756,
#          68.7309635 ,  72.57128945,  76.41161539]),
#  <a list of 10 Patch objects>)

# %%
depthEntries = [t["depthEntries"] for t in results]
f = open("southWest2017.csv","w")
f.write("tSamp,outlierness\n")
assert(len(results["depthEntries" == 365]))
index = 0
for entry in depthEntries:
    tStamp = initialTime + index*stepSize
    f.write("%d,%f\n" % (tStamp,2*entry/numCompanies))
    index = index+1
f.close()

# %%
xs = [math.fabs(np.median(t["nonNegativeEntries"])-0.5) for t in results]
ys = [t["numNegativeEntries"] for t in results]
f = open("strangeDaysAtlanta2017.csv","w")
f.write("t,x,y\n")
for i in xrange(len(xs)):
    tStamp = (initialTime + i*stepSize)
    f.write("%d,%f,%f\n"%(tStamp,xs[i],ys[i]))
f.close()
# Out:
# 1483228800
# 1483315200
# 1483401600
# 1483488000
# 1483574400
# 1483660800
# 1483747200
# 1483833600
# 1483920000
# 1484006400
# 1484092800
# 1484179200
# 1484265600
# 1484352000
# 1484438400
# 1484524800
# 1484611200
# 1484697600
# 1484784000
# 1484870400
# 1484956800
# 1485043200
# 1485129600
# 1485216000
# 1485302400
# 1485388800
# 1485475200
# 1485561600
# 1485648000
# 1485734400
# 1485820800
# 1485907200
# 1485993600
# 1486080000
# 1486166400
# 1486252800
# 1486339200
# 1486425600
# 1486512000
# 1486598400
# 1486684800
# 1486771200
# 1486857600
# 1486944000
# 1487030400
# 1487116800
# 1487203200
# 1487289600
# 1487376000
# 1487462400
# 1487548800
# 1487635200
# 1487721600
# 1487808000
# 1487894400
# 1487980800
# 1488067200
# 1488153600
# 1488240000
# 1488326400
# 1488412800
# 1488499200
# 1488585600
# 1488672000
# 1488758400
# 1488844800
# 1488931200
# 1489017600
# 1489104000
# 1489190400
# 1489276800
# 1489363200
# 1489449600
# 1489536000
# 1489622400
# 1489708800
# 1489795200
# 1489881600
# 1489968000
# 1490054400
# 1490140800
# 1490227200
# 1490313600
# 1490400000
# 1490486400
# 1490572800
# 1490659200
# 1490745600
# 1490832000
# 1490918400
# 1491004800
# 1491091200
# 1491177600
# 1491264000
# 1491350400
# 1491436800
# 1491523200
# 1491609600
# 1491696000
# 1491782400
# 1491868800
# 1491955200
# 1492041600
# 1492128000
# 1492214400
# 1492300800
# 1492387200
# 1492473600
# 1492560000
# 1492646400
# 1492732800
# 1492819200
# 1492905600
# 1492992000
# 1493078400
# 1493164800
# 1493251200
# 1493337600
# 1493424000
# 1493510400
# 1493596800
# 1493683200
# 1493769600
# 1493856000
# 1493942400
# 1494028800
# 1494115200
# 1494201600
# 1494288000
# 1494374400
# 1494460800
# 1494547200
# 1494633600
# 1494720000
# 1494806400
# 1494892800
# 1494979200
# 1495065600
# 1495152000
# 1495238400
# 1495324800
# 1495411200
# 1495497600
# 1495584000
# 1495670400
# 1495756800
# 1495843200
# 1495929600
# 1496016000
# 1496102400
# 1496188800
# 1496275200
# 1496361600
# 1496448000
# 1496534400
# 1496620800
# 1496707200
# 1496793600
# 1496880000
# 1496966400
# 1497052800
# 1497139200
# 1497225600
# 1497312000
# 1497398400
# 1497484800
# 1497571200
# 1497657600
# 1497744000
# 1497830400
# 1497916800
# 1498003200
# 1498089600
# 1498176000
# 1498262400
# 1498348800
# 1498435200
# 1498521600
# 1498608000
# 1498694400
# 1498780800
# 1498867200
# 1498953600
# 1499040000
# 1499126400
# 1499212800
# 1499299200
# 1499385600
# 1499472000
# 1499558400
# 1499644800
# 1499731200
# 1499817600
# 1499904000
# 1499990400
# 1500076800
# 1500163200
# 1500249600
# 1500336000
# 1500422400
# 1500508800
# 1500595200
# 1500681600
# 1500768000
# 1500854400
# 1500940800
# 1501027200
# 1501113600
# 1501200000
# 1501286400
# 1501372800
# 1501459200
# 1501545600
# 1501632000
# 1501718400
# 1501804800
# 1501891200
# 1501977600
# 1502064000
# 1502150400
# 1502236800
# 1502323200
# 1502409600
# 1502496000
# 1502582400
# 1502668800
# 1502755200
# 1502841600
# 1502928000
# 1503014400
# 1503100800
# 1503187200
# 1503273600
# 1503360000
# 1503446400
# 1503532800
# 1503619200
# 1503705600
# 1503792000
# 1503878400
# 1503964800
# 1504051200
# 1504137600
# 1504224000
# 1504310400
# 1504396800
# 1504483200
# 1504569600
# 1504656000
# 1504742400
# 1504828800
# 1504915200
# 1505001600
# 1505088000
# 1505174400
# 1505260800
# 1505347200
# 1505433600
# 1505520000
# 1505606400
# 1505692800
# 1505779200
# 1505865600
# 1505952000
# 1506038400
# 1506124800
# 1506211200
# 1506297600
# 1506384000
# 1506470400
# 1506556800
# 1506643200
# 1506729600
# 1506816000
# 1506902400
# 1506988800
# 1507075200
# 1507161600
# 1507248000
# 1507334400
# 1507420800
# 1507507200
# 1507593600
# 1507680000
# 1507766400
# 1507852800
# 1507939200
# 1508025600
# 1508112000
# 1508198400
# 1508284800
# 1508371200
# 1508457600
# 1508544000
# 1508630400
# 1508716800
# 1508803200
# 1508889600
# 1508976000
# 1509062400
# 1509148800
# 1509235200
# 1509321600
# 1509408000
# 1509494400
# 1509580800
# 1509667200
# 1509753600
# 1509840000
# 1509926400
# 1510012800
# 1510099200
# 1510185600
# 1510272000
# 1510358400
# 1510444800
# 1510531200
# 1510617600
# 1510704000
# 1510790400
# 1510876800
# 1510963200
# 1511049600
# 1511136000
# 1511222400
# 1511308800
# 1511395200
# 1511481600
# 1511568000
# 1511654400
# 1511740800
# 1511827200
# 1511913600
# 1512000000
# 1512086400
# 1512172800
# 1512259200
# 1512345600
# 1512432000
# 1512518400
# 1512604800
# 1512691200
# 1512777600
# 1512864000
# 1512950400
# 1513036800
# 1513123200
# 1513209600
# 1513296000
# 1513382400
# 1513468800
# 1513555200
# 1513641600
# 1513728000
# 1513814400
# 1513900800
# 1513987200
# 1514073600
# 1514160000
# 1514246400
# 1514332800
# 1514419200
# 1514505600
# 1514592000
# 1514678400

# %%
plt.plot(xrange(365),[math.fabs(t-0.5) for t in xs])

# %%
specialDays = set([1009152000,1009238400,1000252800,1009756800])
colors = []
for i in xrange(numTimeSteps):
    day = (initialTime + i*stepSize)
    if day in specialDays:
        colors.append("red")
        plt.annotate(str(i),[xs[i],ys[i]])
        print "day",day,xs[i],ys[i]
    else:
        colors.append("b")
        plt.annotate(str(i),[xs[i],ys[i]])

plt.scatter(xs,ys,c=colors)

# %%
tStamp = (initialTime + 21*stepSize)
print str(tStamp)+":"+str(tStamp+stepSize)
datetime.datetime.utcfromtimestamp(tStamp)
datetime.datetime.utcfromtimestamp(tStamp)
# Out:
# 1485043200:1485129600
# datetime.datetime(2017, 1, 22, 0, 0)

# %%
numTimeSteps
# Out:
# 365

# %%
r = requests.get("http://localhost:7001/api/pipeline/join=right_join/threshold=0/source/aggr=average.arr_delay_g/dataset=on_time_performance/
                 const=origin_airport.tile.(9:11:5:5)/group=origin_airport/const=crs_dep_time.interval.(1000166400:1000252800)/destination/aggr=inverse.arr_delay_t.($)/dataset=on_time_performance/const=origin_airport.tile.(9:11:5:5)/group=origin_airport/const=crs_dep_time.interval.(978307200:1009756800)")
x = json.loads(r.text)
x[0][12][4]<0
# Out:
# True

# %%
findStrangenessCoef(1000166400, 1000252800)
# Out:
# [[[316,369,10,-1.692307710647583,0.30376702547073367],[312,373,10,-0.7096773982048035,0.5351284146308899],[291,375,10,-1.0222222805023194,0.5755413174629211],[295,375,10,-1.774193525314331,0.5792249441146851],[288,376,10,-1.2711864709854127,0.4455758035182953],[308,376,10,-0.6666666865348816,0.39527395367622378],[302,377,10,-1.4583333730697632,0.4300578832626343],[310,378,10,-0.5425790548324585,0.41886046528816225],[307,379,10,1.0,0.7688880562782288],[305,380,10,-0.7653061151504517,0.4596281349658966],[308,381,10,0.27586206793785097,0.6923276782035828],[303,370,10,-1.4615384340286255,0.5229466557502747],[294,378,10,"NaN",-1.0],[293,379,10,"NaN",-1.0],[295,379,10,"NaN",-1.0],[296,382,10,4.0,0.8642728328704834],[301,382,10,-1.25,0.625629186630249],[302,383,10,1.185185194015503,0.6744548678398132]]]
# http://localhost:7001/api/pipeline/join=right_join/threshold=0/source/aggr=average.dep_delay_g/dataset=on_time_performance/const=origin_airport.tile.(9:11:5:5)/group=origin_airport//const=crs_dep_time.interval.(1000166400:1000252800)/destination/aggr=inverse.dep_delay_t.($)/dataset=on_time_performance/const=origin_airport.tile.(9:11:5:5)/group=origin_airport/
# {'depthEntries': 26.279244638979435,
#  'negativeEntries': -14.0,
#  'numEntries': 207,
#  'numNegativeEntries': 14}

# %%
range(0,1)
# Out:
# [0]
